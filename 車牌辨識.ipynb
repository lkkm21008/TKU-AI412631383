# %% [markdown]
# <a href="https://colab.research.google.com/github/lkkm21008/TKU-AI412631383/blob/main/%E8%BB%8A%E7%89%8C%E8%BE%A8%E8%AD%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr #下載easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 53.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 39.0 MB/s eta 0:00:00
# ...

# %%
import easyocr #導入easyocr語庫
import matplotlib.pyplot as plt #導入matplotlib語庫
import cv2 #導入opencv語庫
from google.colab import files #從Google Colab導入files模塊的語句
from IPython.display import Image #從IPython的display模組導入Image類別的語句。這個類別可以用來在Jupyter Notebook或Google Colab中顯示圖片

# %%
img = files.upload() #輸入儲存在Colab中的圖片檔名 #用於在Google Colab中上傳檔案的程式碼行
# Out:
#      <input type="file" id="files-c9e7f433-89ff-4101-8c21-9cb5a85df290" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9e7f433-89ff-4101-8c21-9cb5a85df290">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('S__86753284.jpg') #用OpenCV庫中的函數來讀取影像檔的程式碼

# %%
Image('S__86753284.jpg')

# %%
ocr = easyocr.Reader(['en']) #建立了一個EasyOCR的Reader對象，並指定了要辨識的語言為英語
# Out:
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
allowlist = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890-'
result = reader.readtext(img, allowlist=allowlist)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3807dd6ddeb5> in <cell line: 2>()
#       1 allowlist = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890-'
# ----> 2 result = reader.readtext(img, allowlist=allowlist)
#       3 print(result)
#
# NameError: name 'reader' is not defined

# %%
for i in range(len(resce)):
    resceunpack = resce[i]
    plate = resceunpack[1]

    if 6 <= len(plate) <= 9:
        print(plate)
    else:
        print("輸入圖片非車牌")
#篩選出在指定長度範圍內的潛在車牌號碼並將其列印出來，同時提供了一個備用訊息以處理未識別到車牌號碼的情況。
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-26a763c5f1ca> in <cell line: 1>()
# ----> 1 for i in range(len(resce)):
#       2     resceunpack = resce[i]
#       3     plate = resceunpack[1]
#       4
#       5     if 6 <= len(plate) <= 9:
#
# NameError: name 'resce' is not defined
